# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
movies = pd.read_csv("Movie+Assignment+Data.csv")
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
print(movies.columns)
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
print(movies.shape)
# Out:
# (5043, 28)

# %%
print(type(movies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum(axis=0)
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
len(movies)
# Out:
# 5043

# %%
# Write your code for column-wise null percentages here
round((movies.isnull().sum() / len(movies) ) * 100, 2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

movies_update1 = movies.drop(columns = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords'])
movies_update1
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
percentage_column = round((movies_update1.isnull().sum() / len(movies) ) * 100, 2)
percentage_column_check = percentage_column[percentage_column > 5].index
percentage_column_check
# Out:
# Index(['gross', 'budget'], dtype='object')

# %%
movies_update2 = movies_update1.dropna(subset = ['gross', 'budget'], ignore_index = True)
movies_update2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3886      Shane Carruth                   143.0     424760.0
# 3887   Neill Dela Llana                    35.0      70071.0
# 3888   Robert Rodriguez                    56.0    2040920.0
# 3889       Edward Burns                    14.0       4584.0
# 3890           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here

movies_update2[movies_update2.isnull().sum(axis=1) >5].index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
movies_update2.isnull().sum(axis= 0)
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  4
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
# Write your code for filling the NaN values in the 'language' column here

movies_update2['language'] = movies_update2['language'].fillna("English")
movies_update2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3886      Shane Carruth                   143.0     424760.0
# 3887   Neill Dela Llana                    35.0      70071.0
# 3888   Robert Rodriguez                    56.0    2040920.0
# 3889       Edward Burns                    14.0       4584.0
# 3890           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies_update2.isnull().sum(axis =0)
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  0
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
movies_cleaned = movies_update2

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here

movies_cleaned.index
# Out:
# RangeIndex(start=0, stop=3891, step=1)

# %%
len(movies_cleaned)
# Out:
# 3891

# %%
round( len(movies_cleaned) / len(movies) * 100 , 2)
# Out:
# 77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
movies_cleaned
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3886      Shane Carruth                   143.0     424760.0
# 3887   Neill Dela Llana                    35.0      70071.0
# 3888   Robert Rodriguez                    56.0    2040920.0
# 3889       Edward Burns                    14.0       4584.0
# 3890           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# Write your code for unit conversion here

movies_cleaned[['gross', 'budget']] = movies_cleaned[['gross', 'budget']] / 1000000

movies_cleaned
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 4        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 3886      Shane Carruth                   143.0    0.424760
# 3887   Neill Dela Llana                    35.0    0.070071
# 3888   Robert Rodriguez                    56.0    2.040920
# 3889       Edward Burns                    14.0    0.004584
# 3890           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here

movies_cleaned['Profit'] = movies_cleaned['gross'] - movies_cleaned['budget']

movies_cleaned
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 4        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 3886      Shane Carruth                   143.0    0.424760
# 3887   Neill Dela Llana                    35.0    0.070071
# 3888   Robert Rodriguez                    56.0    2.040920
# 3889       Edward Burns                    14.0    0.004584
# 3890           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Write your code for sorting the dataframe here

movies_cleaned.sort_values(by = 'Profit' , ascending = False, inplace = True)

movies_cleaned
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2726      George Lucas                   282.0  460.935665
# 2770  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2160   Katsuhiro Ôtomo                   105.0    0.410388
# 2149    Hayao Miyazaki                   174.0    2.298191
# 2715      Lajos Koltai                    73.0    0.195888
# 3309    Chan-wook Park                   202.0    0.211667
# 2700      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
 # Write your code to get the top 10 profiting movies here
top10 = movies_cleaned[:10]
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 28      Colin Trevorrow                   644.0  652.177271
# 25        James Cameron                   315.0  658.672302
# 2726       George Lucas                   282.0  460.935665
# 2770   Steven Spielberg                   215.0  434.949459
# 758         Joss Whedon                   703.0  623.279547
# 16          Joss Whedon                   703.0  623.279547
# 487        Roger Allers                   186.0  422.783777
# 232        George Lucas                   320.0  474.544677
# 64    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 25                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here

movies_cleaned.drop_duplicates(inplace = True)
movies_cleaned
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2726      George Lucas                   282.0  460.935665
# 2770  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2160   Katsuhiro Ôtomo                   105.0    0.410388
# 2149    Hayao Miyazaki                   174.0    2.298191
# 2715      Lajos Koltai                    73.0    0.195888
# 3309    Chan-wook Park                   202.0    0.211667
# 2700      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write code for repeating subtask 2 here

top10 = movies_cleaned[:10]
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 28      Colin Trevorrow                   644.0  652.177271
# 25        James Cameron                   315.0  658.672302
# 2726       George Lucas                   282.0  460.935665
# 2770   Steven Spielberg                   215.0  434.949459
# 758         Joss Whedon                   703.0  623.279547
# 487        Roger Allers                   186.0  422.783777
# 232        George Lucas                   320.0  474.544677
# 64    Christopher Nolan                   645.0  533.316061
# 424           Gary Ross                   673.0  407.999255
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 25                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

voted_users = movies_cleaned[movies_cleaned['num_voted_users'] > 25000]

dscending_imdb = voted_users.sort_values(by = "imdb_score", ascending = False, ignore_index = True)

IMDb_Top_250 = dscending_imdb[:250]

Rank_data = range(1,251)

IMDb_Top_250.insert(1, "Rank", Rank_data)

IMDb_Top_250
# Out:
#             director_name  Rank  num_critic_for_reviews       gross  \
# 0          Frank Darabont     1                   199.0   28.341469
# 1    Francis Ford Coppola     2                   208.0  134.821952
# 2    Francis Ford Coppola     3                   149.0   57.300000
# 3       Christopher Nolan     4                   645.0  533.316061
# 4        Steven Spielberg     5                   174.0   96.067179
# ..                    ...   ...                     ...         ...
# 245           Yash Chopra   246                    29.0    2.921738
# 246               Ang Lee   247                   287.0  128.067808
# 247          Dean DeBlois   248                   292.0  176.997107
# 248            Tim Burton   249                   148.0    5.887457
# 249         James Mangold   250                   291.0  119.518352
#
#                                                genres           actor_1_name  \
# ...

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here

Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']

Top_Foreign_Lang_Film
# Out:
#                         director_name  Rank  num_critic_for_reviews  \
# 7                        Sergio Leone     8                   181.0
# 13                     Akira Kurosawa    14                   153.0
# 18                 Fernando Meirelles    19                   214.0
# 23                     Hayao Miyazaki    24                   246.0
# 28   Florian Henckel von Donnersmarck    29                   215.0
# 38                       Majid Majidi    39                    46.0
# 46                     Chan-wook Park    47                   305.0
# 47                     Hayao Miyazaki    48                   174.0
# 48                     Asghar Farhadi    49                   354.0
# 53                  Wolfgang Petersen    54                    96.0
# 56                 Jean-Pierre Jeunet    57                   242.0
# 58                     S.S. Rajamouli    59                    44.0
# 65                  Thomas Vinterberg    66                   349.0
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
movies_cleaned
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2726      George Lucas                   282.0  460.935665
# 2770  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2160   Katsuhiro Ôtomo                   105.0    0.410388
# 2149    Hayao Miyazaki                   174.0    2.298191
# 2715      Lajos Koltai                    73.0    0.195888
# 3309    Chan-wook Park                   202.0    0.211667
# 2700      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write your code for extracting the top 10 directors here

director_imdb = movies_cleaned.groupby(['director_name'])[['imdb_score']].mean()

sort_director_imdb = director_imdb.sort_values('imdb_score', ascending = False)

top10director = sort_director_imdb.head(10)

top10director
# Out:
#                    imdb_score
# director_name
# Charles Chaplin      8.600000
# Tony Kaye            8.600000
# Alfred Hitchcock     8.500000
# Majid Majidi         8.500000
# Ron Fricke           8.500000
# Damien Chazelle      8.500000
# Sergio Leone         8.433333
# Christopher Nolan    8.425000
# S.S. Rajamouli       8.400000
# Asghar Farhadi       8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here

movies_cleaned['genre_1'] = movies_cleaned['genres'].apply(lambda x : "|".join(x.split('|')[:1]))

movies_cleaned['genre_2'] =  movies_cleaned['genres'].apply(lambda x : "|".join(x.split('|')[1:2]))

movies_cleaned
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2726      George Lucas                   282.0  460.935665
# 2770  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2160   Katsuhiro Ôtomo                   105.0    0.410388
# 2149    Hayao Miyazaki                   174.0    2.298191
# 2715      Lajos Koltai                    73.0    0.195888
# 3309    Chan-wook Park                   202.0    0.211667
# 2700      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
movies_cleaned[['genre_1', 'genre_2']]
# Out:
#         genre_1    genre_2
# 0        Action  Adventure
# 28       Action  Adventure
# 25        Drama    Romance
# 2726     Action  Adventure
# 2770     Family     Sci-Fi
# ...         ...        ...
# 2160     Action  Adventure
# 2149  Adventure  Animation
# 2715      Drama    Romance
# 3309      Crime      Drama
# 2700     Comedy      Drama
#
# [3856 rows x 2 columns]

# %%
 # Write your code for grouping the dataframe here

movies_by_segment = movies_cleaned.groupby(['genre_1', 'genre_2'])

movies_by_segment

# %%
 # Write your code for getting the 5 most popular combo of genres here


PopGenre = movies_by_segment[['gross']].mean()

PopGenre
# Out:
#                          gross
# genre_1  genre_2
# Action               59.520907
#          Adventure  109.595465
#          Animation   92.680515
#          Biography   44.355422
#          Comedy      53.038158
# ...                        ...
# Romance  Sci-Fi      62.453315
# Sci-Fi                0.018195
#          Thriller    29.793790
# Thriller              0.040513
# Western              15.914589
#
# [103 rows x 1 columns]

# %%
PopGenre.sort_values(by = "gross", ascending = False).head(5)
# Out:
#                           gross
# genre_1   genre_2
# Family    Sci-Fi     434.949459
# Adventure Sci-Fi     228.627758
#           Family     118.919540
#           Animation  116.998550
# Action    Adventure  109.595465

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
movies_cleaned
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 28     Colin Trevorrow                   644.0  652.177271
# 25       James Cameron                   315.0  658.672302
# 2726      George Lucas                   282.0  460.935665
# 2770  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2160   Katsuhiro Ôtomo                   105.0    0.410388
# 2149    Hayao Miyazaki                   174.0    2.298191
# 2715      Lajos Koltai                    73.0    0.195888
# 3309    Chan-wook Park                   202.0    0.211667
# 2700      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write your code for creating three new dataframes here

# Include all movies in which Meryl_Streep is the lead

Meryl_Streep = movies_cleaned.loc[movies_cleaned.actor_1_name == 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1332   David Frankel                   208.0  124.732962
# 1482  Sydney Pollack                    66.0   87.100000
# 1140     Nora Ephron                   252.0   94.125426
# 1525   David Frankel                   234.0   63.536011
# 397     Nancy Meyers                   187.0  112.703470
# 2520  Phyllida Lloyd                   331.0   29.959436
# 1795  Stephen Daldry                   174.0   41.597830
# 2816   Robert Altman                   211.0   20.338609
# 1046   Curtis Hanson                    42.0   46.815748
# 1574   Carl Franklin                    64.0   23.209440
# 1401  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 1332             Comedy|Drama|Romance  Meryl Streep
# 1482          Biography|Drama|Romance  Meryl Streep
# 1140          Biography|Drama|Romance  Meryl Streep
# 1525             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
# Include all movies in which Leo_Caprio is the lead

Leo_Caprio = movies_cleaned.loc[movies_cleaned.actor_1_name == 'Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 25            James Cameron                   315.0  658.672302
# 94        Christopher Nolan                   642.0  292.568851
# 867        Steven Spielberg                   194.0  164.435221
# 285       Quentin Tarantino                   765.0  162.804648
# 174   Alejandro G. Iñárritu                   556.0  183.635922
# 436         Martin Scorsese                   490.0  127.968405
# 350         Martin Scorsese                   352.0  132.373442
# 3050           Baz Luhrmann                   490.0  144.812796
# 49             Baz Luhrmann                   490.0  144.812796
# 2502           Baz Luhrmann                   106.0   46.338728
# 1346        Randall Wallace                    83.0   56.876365
# 297         Martin Scorsese                   606.0  116.866727
# 1375         Clint Eastwood                   392.0   37.304950
# 248         Martin Scorsese                   267.0  102.608827
# ...

# %%
 # Include all movies in which Brad_Pitt is the lead

Brad_Pitt = movies_cleaned.loc[movies_cleaned.actor_1_name == 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 388       Steven Soderbergh                   186.0  183.405771
# 246              Doug Liman                   233.0  186.336103
# 895             Neil Jordan                   120.0  105.264608
# 453              David Ayer                   406.0   85.707116
# 245       Steven Soderbergh                   198.0  125.531634
# 2042  Alejandro G. Iñárritu                   285.0   34.300771
# 2446         Andrew Dominik                   414.0   14.938570
# 2623             Tony Scott                   122.0   12.281500
# 2159    Angelina Jolie Pitt                   131.0    0.531009
# 1408        Terrence Malick                   584.0   13.303319
# 97            David Fincher                   362.0  127.490802
# 653           David Fincher                   315.0   37.023395
# 1619         Andrew Dominik                   273.0    3.904982
# 585     Jean-Jacques Annaud                    76.0   37.901509
# ...

# %%
# Write your code for combining the three dataframes here

combined = pd.concat([Meryl_Streep , Leo_Caprio, Brad_Pitt])

combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 1332          David Frankel                   208.0  124.732962
# 1482         Sydney Pollack                    66.0   87.100000
# 1140            Nora Ephron                   252.0   94.125426
# 1525          David Frankel                   234.0   63.536011
# 397            Nancy Meyers                   187.0  112.703470
# 2520         Phyllida Lloyd                   331.0   29.959436
# 1795         Stephen Daldry                   174.0   41.597830
# 2816          Robert Altman                   211.0   20.338609
# 1046          Curtis Hanson                    42.0   46.815748
# 1574          Carl Franklin                    64.0   23.209440
# 1401         Robert Redford                   227.0   14.998070
# 25            James Cameron                   315.0  658.672302
# 94        Christopher Nolan                   642.0  292.568851
# 867        Steven Spielberg                   194.0  164.435221
# ...

# %%
# Write your code for grouping the combined dataframe here

combined_by_segment = combined.groupby('actor_1_name')

combined_by_segment

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

mean = combined_by_segment[['num_critic_for_reviews']].mean()

mean.sort_values(by = 'num_critic_for_reviews', ascending = False)
# Out:
#                    num_critic_for_reviews
# actor_1_name
# Leonardo DiCaprio              330.190476
# Brad Pitt                      245.000000
# Meryl Streep                   181.454545

# %%
mean = combined_by_segment[['num_user_for_reviews']].mean()

mean.sort_values(by = 'num_user_for_reviews', ascending = False)
# Out:
#                    num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio            914.476190
# Brad Pitt                    742.352941
# Meryl Streep                 297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
